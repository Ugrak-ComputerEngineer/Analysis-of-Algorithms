# %%
def fibo_loop_1(a,b,n):
    if(n>0):
        print (a,b,n)
        n=n-1
        t=a
        a=b
        b=t+b
        fibo_loop_1(b,a+b,n)
    else:
        return a

s=fibo_loop_1(0,1,10)
print(s)

import time
def fibo_loop(n):
    if (n<2):
        return n
    else:
        a=0
        b=1
        while(n>1):
            c=a+b
            a=b
            b=c
            n=n-1
    return c

def fibo_rec(n):
    if (n<2):
        return n
    else:
        return fibo_rec(n-1)+fibo_rec(n-2)

for n in range(40):
    time_1=int (round(time.time()))
    fibo_rec(n)
    time_2=int (round(time.time()))
    print("recursive np olan: ",n," icin gecen sure: ", time_2-time_1, "saniye")
    time_1=int (round(time.time()))
    fibo_loop(n)
    time_2=int (round(time.time()))
    print(" -------------------------- ")
    print("loop p(lineer) olan: ",n," icin gecen sure: ", time_2-time_1, "saniye")
# Out:
# 0 1 10
# 1 2 9
# 3 5 8
# 8 13 7
# 21 34 6
# 55 89 5
# 144 233 4
# 377 610 3
# 987 1597 2
# 2584 4181 1
# None
# recursive np olan:  0  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  0  icin gecen sure:  0 saniye
# recursive np olan:  1  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  1  icin gecen sure:  0 saniye
# recursive np olan:  2  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  2  icin gecen sure:  0 saniye
# recursive np olan:  3  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  3  icin gecen sure:  0 saniye
# recursive np olan:  4  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  4  icin gecen sure:  0 saniye
# recursive np olan:  5  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  5  icin gecen sure:  0 saniye
# recursive np olan:  6  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  6  icin gecen sure:  0 saniye
# recursive np olan:  7  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  7  icin gecen sure:  0 saniye
# recursive np olan:  8  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  8  icin gecen sure:  0 saniye
# recursive np olan:  9  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  9  icin gecen sure:  0 saniye
# recursive np olan:  10  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  10  icin gecen sure:  0 saniye
# recursive np olan:  11  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  11  icin gecen sure:  0 saniye
# recursive np olan:  12  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  12  icin gecen sure:  0 saniye
# recursive np olan:  13  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  13  icin gecen sure:  0 saniye
# recursive np olan:  14  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  14  icin gecen sure:  0 saniye
# recursive np olan:  15  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  15  icin gecen sure:  0 saniye
# recursive np olan:  16  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  16  icin gecen sure:  0 saniye
# recursive np olan:  17  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  17  icin gecen sure:  0 saniye
# recursive np olan:  18  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  18  icin gecen sure:  0 saniye
# recursive np olan:  19  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  19  icin gecen sure:  0 saniye
# recursive np olan:  20  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  20  icin gecen sure:  0 saniye
# recursive np olan:  21  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  21  icin gecen sure:  0 saniye
# recursive np olan:  22  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  22  icin gecen sure:  0 saniye
# recursive np olan:  23  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  23  icin gecen sure:  0 saniye
# recursive np olan:  24  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  24  icin gecen sure:  0 saniye
# recursive np olan:  25  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  25  icin gecen sure:  0 saniye
# recursive np olan:  26  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  26  icin gecen sure:  0 saniye
# recursive np olan:  27  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  27  icin gecen sure:  0 saniye
# recursive np olan:  28  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  28  icin gecen sure:  0 saniye
# recursive np olan:  29  icin gecen sure:  0 saniye
#  --------------------------
# loop p(lineer) olan:  29  icin gecen sure:  0 saniye
# recursive np olan:  30  icin gecen sure:  1 saniye
#  --------------------------
# loop p(lineer) olan:  30  icin gecen sure:  0 saniye
# recursive np olan:  31  icin gecen sure:  1 saniye
#  --------------------------
# loop p(lineer) olan:  31  icin gecen sure:  0 saniye
# recursive np olan:  32  icin gecen sure:  1 saniye
#  --------------------------
# loop p(lineer) olan:  32  icin gecen sure:  0 saniye
# recursive np olan:  33  icin gecen sure:  2 saniye
#  --------------------------
# loop p(lineer) olan:  33  icin gecen sure:  0 saniye
# recursive np olan:  34  icin gecen sure:  3 saniye
#  --------------------------
# loop p(lineer) olan:  34  icin gecen sure:  0 saniye
# recursive np olan:  35  icin gecen sure:  5 saniye
#  --------------------------
# loop p(lineer) olan:  35  icin gecen sure:  0 saniye
# recursive np olan:  36  icin gecen sure:  9 saniye
#  --------------------------
# loop p(lineer) olan:  36  icin gecen sure:  0 saniye
# recursive np olan:  37  icin gecen sure:  15 saniye
#  --------------------------
# loop p(lineer) olan:  37  icin gecen sure:  0 saniye
# recursive np olan:  38  icin gecen sure:  21 saniye
#  --------------------------
# loop p(lineer) olan:  38  icin gecen sure:  0 saniye
# recursive np olan:  39  icin gecen sure:  33 saniye
#  --------------------------
# loop p(lineer) olan:  39  icin gecen sure:  0 saniye
